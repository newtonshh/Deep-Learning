# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
boston_housing = tf.keras.datasets.mnist
(train_x, train_y), (test_x, test_y) = boston_housing.load_data()
train_data = np.expand_dims(train_x.astype(np.float32) / 255.0, axis = -1)
test_data = np.expand_dims(test_x.astype(np.float32) / 255.0, axis = -1)

# %%
print(train_x.shape, train_y.shape)

# %%
plt.figure(figsize=[5,5])
plt.scatter(train_x[:,5], train_y)
plt.xlabel("RM")
plt.ylabel("PRICE")
plt.show()

# %%
plt.figure(figsize = (12, 12))
for i in range(13):
    plt.subplot(4, 4, i+1)
    plt.scatter(train_x[:,i], train_y)
    
plt.show()
